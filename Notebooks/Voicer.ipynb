# %%
# !pip install transformers torchaudio librosa soundfile xgboost
# Out:
# Requirement already satisfied: transformers in /usr/local/lib/python3.12/dist-packages (4.57.3)
# Requirement already satisfied: torchaudio in /usr/local/lib/python3.12/dist-packages (2.9.0+cu126)
# Requirement already satisfied: librosa in /usr/local/lib/python3.12/dist-packages (0.11.0)
# Requirement already satisfied: soundfile in /usr/local/lib/python3.12/dist-packages (0.13.1)
# Collecting xgboost==1.7.6
#   Downloading xgboost-1.7.6-py3-none-manylinux2014_x86_64.whl.metadata (1.9 kB)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (from xgboost==1.7.6) (2.0.2)
# Requirement already satisfied: scipy in /usr/local/lib/python3.12/dist-packages (from xgboost==1.7.6) (1.16.3)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from transformers) (3.20.0)
# Requirement already satisfied: huggingface-hub<1.0,>=0.34.0 in /usr/local/lib/python3.12/dist-packages (from transformers) (0.36.0)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from transformers) (25.0)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.12/dist-packages (from transformers) (6.0.3)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.12/dist-packages (from transformers) (2025.11.3)
# Requirement already satisfied: requests in /usr/local/lib/python3.12/dist-packages (from transformers) (2.32.4)
# Requirement already satisfied: tokenizers<=0.23.0,>=0.22.0 in /usr/local/lib/python3.12/dist-packages (from transformers) (0.22.1)
# Requirement already satisfied: safetensors>=0.4.3 in /usr/local/lib/python3.12/dist-packages (from transformers) (0.7.0)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.12/dist-packages (from transformers) (4.67.1)
# Requirement already satisfied: torch==2.9.0 in /usr/local/lib/python3.12/dist-packages (from torchaudio) (2.9.0+cu126)
# Requirement already satisfied: typing-extensions>=4.10.0 in /usr/local/lib/python3.12/dist-packages (from torch==2.9.0->torchaudio) (4.15.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from torch==2.9.0->torchaudio) (75.2.0)
# Requirement already satisfied: sympy>=1.13.3 in /usr/local/lib/python3.12/dist-packages (from torch==2.9.0->torchaudio) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in /usr/local/lib/python3.12/dist-packages (from torch==2.9.0->torchaudio) (3.6)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from torch==2.9.0->torchaudio) (3.1.6)
# Requirement already satisfied: fsspec>=0.8.5 in /usr/local/lib/python3.12/dist-packages (from torch==2.9.0->torchaudio) (2025.3.0)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch==2.9.0->torchaudio) (12.6.77)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch==2.9.0->torchaudio) (12.6.77)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.6.80 in /usr/local/lib/python3.12/dist-packages (from torch==2.9.0->torchaudio) (12.6.80)
# Requirement already satisfied: nvidia-cudnn-cu12==9.10.2.21 in /usr/local/lib/python3.12/dist-packages (from torch==2.9.0->torchaudio) (9.10.2.21)
# Requirement already satisfied: nvidia-cublas-cu12==12.6.4.1 in /usr/local/lib/python3.12/dist-packages (from torch==2.9.0->torchaudio) (12.6.4.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.0.4 in /usr/local/lib/python3.12/dist-packages (from torch==2.9.0->torchaudio) (11.3.0.4)
# Requirement already satisfied: nvidia-curand-cu12==10.3.7.77 in /usr/local/lib/python3.12/dist-packages (from torch==2.9.0->torchaudio) (10.3.7.77)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.1.2 in /usr/local/lib/python3.12/dist-packages (from torch==2.9.0->torchaudio) (11.7.1.2)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.4.2 in /usr/local/lib/python3.12/dist-packages (from torch==2.9.0->torchaudio) (12.5.4.2)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.7.1 in /usr/local/lib/python3.12/dist-packages (from torch==2.9.0->torchaudio) (0.7.1)
# Requirement already satisfied: nvidia-nccl-cu12==2.27.5 in /usr/local/lib/python3.12/dist-packages (from torch==2.9.0->torchaudio) (2.27.5)
# Requirement already satisfied: nvidia-nvshmem-cu12==3.3.20 in /usr/local/lib/python3.12/dist-packages (from torch==2.9.0->torchaudio) (3.3.20)
# Requirement already satisfied: nvidia-nvtx-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch==2.9.0->torchaudio) (12.6.77)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.6.85 in /usr/local/lib/python3.12/dist-packages (from torch==2.9.0->torchaudio) (12.6.85)
# Requirement already satisfied: nvidia-cufile-cu12==1.11.1.6 in /usr/local/lib/python3.12/dist-packages (from torch==2.9.0->torchaudio) (1.11.1.6)
# Requirement already satisfied: triton==3.5.0 in /usr/local/lib/python3.12/dist-packages (from torch==2.9.0->torchaudio) (3.5.0)
# Requirement already satisfied: audioread>=2.1.9 in /usr/local/lib/python3.12/dist-packages (from librosa) (3.1.0)
# Requirement already satisfied: numba>=0.51.0 in /usr/local/lib/python3.12/dist-packages (from librosa) (0.60.0)
# Requirement already satisfied: scikit-learn>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from librosa) (1.6.1)
# Requirement already satisfied: joblib>=1.0 in /usr/local/lib/python3.12/dist-packages (from librosa) (1.5.2)
# Requirement already satisfied: decorator>=4.3.0 in /usr/local/lib/python3.12/dist-packages (from librosa) (4.4.2)
# Requirement already satisfied: pooch>=1.1 in /usr/local/lib/python3.12/dist-packages (from librosa) (1.8.2)
# Requirement already satisfied: soxr>=0.3.2 in /usr/local/lib/python3.12/dist-packages (from librosa) (1.0.0)
# Requirement already satisfied: lazy_loader>=0.1 in /usr/local/lib/python3.12/dist-packages (from librosa) (0.4)
# Requirement already satisfied: msgpack>=1.0 in /usr/local/lib/python3.12/dist-packages (from librosa) (1.1.2)
# Requirement already satisfied: cffi>=1.0 in /usr/local/lib/python3.12/dist-packages (from soundfile) (2.0.0)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.12/dist-packages (from cffi>=1.0->soundfile) (2.23)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.3 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<1.0,>=0.34.0->transformers) (1.2.0)
# Requirement already satisfied: llvmlite<0.44,>=0.43.0dev0 in /usr/local/lib/python3.12/dist-packages (from numba>=0.51.0->librosa) (0.43.0)
# Requirement already satisfied: platformdirs>=2.5.0 in /usr/local/lib/python3.12/dist-packages (from pooch>=1.1->librosa) (4.5.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests->transformers) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests->transformers) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests->transformers) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests->transformers) (2025.11.12)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn>=1.1.0->librosa) (3.6.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy>=1.13.3->torch==2.9.0->torchaudio) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2->torch==2.9.0->torchaudio) (3.0.3)
# Downloading xgboost-1.7.6-py3-none-manylinux2014_x86_64.whl (200.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 200.3/200.3 MB 7.0 MB/s eta 0:00:00
# Installing collected packages: xgboost
#   Attempting uninstall: xgboost
#     Found existing installation: xgboost 3.1.2
#     Uninstalling xgboost-3.1.2:
#       Successfully uninstalled xgboost-3.1.2
# Successfully installed xgboost-1.7.6

# %%
import os
import librosa
import numpy as np
import torch
from transformers import Wav2Vec2FeatureExtractor, Wav2Vec2Model
from xgboost import XGBClassifier
from sklearn.metrics import accuracy_score, classification_report
import pickle
from tqdm import tqdm

# %%
device = "cuda" if torch.cuda.is_available() else "cpu"
print("Using device:", device)

processor = Wav2Vec2FeatureExtractor.from_pretrained("facebook/wav2vec2-xls-r-300m")
model = Wav2Vec2Model.from_pretrained("facebook/wav2vec2-xls-r-300m")
model.to(device)
# Out:
# Using device: cuda
# pytorch_model.bin:   0%|          | 0.00/1.27G [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/1.27G [00:00<?, ?B/s]
# Wav2Vec2Model(
#   (feature_extractor): Wav2Vec2FeatureEncoder(
#     (conv_layers): ModuleList(
#       (0): Wav2Vec2LayerNormConvLayer(
#         (conv): Conv1d(1, 512, kernel_size=(10,), stride=(5,))
#         (layer_norm): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#         (activation): GELUActivation()
#       )
#       (1-4): 4 x Wav2Vec2LayerNormConvLayer(
#         (conv): Conv1d(512, 512, kernel_size=(3,), stride=(2,))
#         (layer_norm): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#         (activation): GELUActivation()
#       )
#       (5-6): 2 x Wav2Vec2LayerNormConvLayer(
#         (conv): Conv1d(512, 512, kernel_size=(2,), stride=(2,))
#         (layer_norm): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#         (activation): GELUActivation()
#       )
#     )
#   )
#   (feature_projection): Wav2Vec2FeatureProjection(
#     (layer_norm): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#     (projection): Linear(in_features=512, out_features=1024, bias=True)
#     (dropout): Dropout(p=0.1, inplace=False)
#   )
#   (encoder): Wav2Vec2EncoderStableLayerNorm(
#     (pos_conv_embed): Wav2Vec2PositionalConvEmbedding(
#       (conv): ParametrizedConv1d(
#         1024, 1024, kernel_size=(128,), stride=(1,), padding=(64,), groups=16
#         (parametrizations): ModuleDict(
#           (weight): ParametrizationList(
#             (0): _WeightNorm()
#           )
#         )
#       )
#       (padding): Wav2Vec2SamePadLayer()
#       (activation): GELUActivation()
#     )
#     (layer_norm): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#     (dropout): Dropout(p=0.1, inplace=False)
#     (layers): ModuleList(
#       (0-23): 24 x Wav2Vec2EncoderLayerStableLayerNorm(
#         (attention): Wav2Vec2Attention(
#           (k_proj): Linear(in_features=1024, out_features=1024, bias=True)
#           (v_proj): Linear(in_features=1024, out_features=1024, bias=True)
#           (q_proj): Linear(in_features=1024, out_features=1024, bias=True)
#           (out_proj): Linear(in_features=1024, out_features=1024, bias=True)
#         )
#         (dropout): Dropout(p=0.1, inplace=False)
#         (layer_norm): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#         (feed_forward): Wav2Vec2FeedForward(
#           (intermediate_dropout): Dropout(p=0.0, inplace=False)
#           (intermediate_dense): Linear(in_features=1024, out_features=4096, bias=True)
#           (intermediate_act_fn): GELUActivation()
#           (output_dense): Linear(in_features=4096, out_features=1024, bias=True)
#           (output_dropout): Dropout(p=0.1, inplace=False)
#         )
#         (final_layer_norm): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#       )
#     )
#   )
# )

# %%
def extract_embedding(audio_path, target_sr=16000):
    audio, sr = librosa.load(audio_path, sr=target_sr)
    audio = torch.tensor(audio).float()
    inputs = processor(audio, sampling_rate=target_sr, return_tensors="pt", padding=True)
    inputs = {k: v.to(device) for k, v in inputs.items()}

    with torch.no_grad():
        features = model(**inputs).last_hidden_state

    return features.mean(dim=1).cpu().numpy().flatten()

# %%
def load_split(split_path, cache_embeddings=True, cache_file=None):
    if cache_embeddings and cache_file and os.path.exists(cache_file):
        print(f"Loading cached embeddings from {cache_file}...")
        data = np.load(cache_file, allow_pickle=True)
        return data['X'], data['y']

    X, y = [], []
    for label, subfolder in enumerate(["real", "fake"]):
        folder = os.path.join(split_path, subfolder)
        print(f"Loading {subfolder} voices from: {folder}")
        for file in tqdm(os.listdir(folder)):
            if file.endswith(".wav"):
                emb = extract_embedding(os.path.join(folder, file))
                X.append(emb)
                y.append(label)

    X = np.array(X)
    y = np.array(y)

    if cache_embeddings and cache_file:
        np.savez_compressed(cache_file, X=X, y=y)
        print(f"Saved embeddings to {cache_file}")

    return X, y

# %%
DATASET_ROOT = "/content/drive/MyDrive/dataset/voices/"

X_train, y_train = load_split(os.path.join(DATASET_ROOT, "training"), cache_file="train_embeddings.npz")
X_val, y_val     = load_split(os.path.join(DATASET_ROOT, "validation"), cache_file="val_embeddings.npz")
X_test, y_test   = load_split(os.path.join(DATASET_ROOT, "testing"), cache_file="test_embeddings.npz")

print("Dataset sizes:")
print(" Train:", X_train.shape)
print(" Val:  ", X_val.shape)
print(" Test: ", X_test.shape)
# Out:
# Loading real voices from: /content/drive/MyDrive/dataset/voices/training/real
# 100%|██████████| 6978/6978 [07:14<00:00, 16.06it/s]
# Loading fake voices from: /content/drive/MyDrive/dataset/voices/training/fake
# 100%|██████████| 6978/6978 [07:06<00:00, 16.35it/s]
# Saved embeddings to train_embeddings.npz
# Loading real voices from: /content/drive/MyDrive/dataset/voices/validation/real
# 100%|██████████| 1413/1413 [01:17<00:00, 18.19it/s]
# Loading fake voices from: /content/drive/MyDrive/dataset/voices/validation/fake
# 100%|██████████| 1413/1413 [01:18<00:00, 17.95it/s]
# Saved embeddings to val_embeddings.npz
# Loading real voices from: /content/drive/MyDrive/dataset/voices/testing/real
# 100%|██████████| 544/544 [00:28<00:00, 19.36it/s]
# Loading fake voices from: /content/drive/MyDrive/dataset/voices/testing/fake
# 100%|██████████| 544/544 [00:27<00:00, 19.76it/s]
# Saved embeddings to test_embeddings.npz
# Dataset sizes:
#  Train: (13956, 1024)
#  Val:   (2826, 1024)
#  Test:  (1088, 1024)

# %%
model_xgb = XGBClassifier(
    n_estimators=1000,
    learning_rate=0.03,
    max_depth=7,
    subsample=0.9,
    colsample_bytree=0.9,
    eval_metric="logloss",
    tree_method="gpu_hist",
    predictor="gpu_predictor"
)

model_xgb.fit(
    X_train, y_train,
    eval_set=[(X_val, y_val)],
    early_stopping_rounds=30,
    verbose=True
)
# Out:
# /usr/local/lib/python3.12/dist-packages/xgboost/sklearn.py:835: UserWarning: `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
#   warnings.warn(
# [0]	validation_0-logloss:0.67271
# [1]	validation_0-logloss:0.65367
# [2]	validation_0-logloss:0.63478
# [3]	validation_0-logloss:0.61760
# [4]	validation_0-logloss:0.60119
# [5]	validation_0-logloss:0.58516
# [6]	validation_0-logloss:0.56982
# [7]	validation_0-logloss:0.55556
# [8]	validation_0-logloss:0.54138
# [9]	validation_0-logloss:0.52759
# [10]	validation_0-logloss:0.51478
# [11]	validation_0-logloss:0.50238
# [12]	validation_0-logloss:0.49061
# [13]	validation_0-logloss:0.47907
# [14]	validation_0-logloss:0.46820
# [15]	validation_0-logloss:0.45734
# [16]	validation_0-logloss:0.44673
# [17]	validation_0-logloss:0.43714
# [18]	validation_0-logloss:0.42787
# [19]	validation_0-logloss:0.41880
# [20]	validation_0-logloss:0.41004
# [21]	validation_0-logloss:0.40124
# [22]	validation_0-logloss:0.39265
# [23]	validation_0-logloss:0.38484
# [24]	validation_0-logloss:0.37708
# [25]	validation_0-logloss:0.36952
# [26]	validation_0-logloss:0.36224
# [27]	validation_0-logloss:0.35524
# [28]	validation_0-logloss:0.34825
# [29]	validation_0-logloss:0.34142
# [30]	validation_0-logloss:0.33478
# [31]	validation_0-logloss:0.32846
# [32]	validation_0-logloss:0.32233
# [33]	validation_0-logloss:0.31620
# [34]	validation_0-logloss:0.31038
# [35]	validation_0-logloss:0.30455
# [36]	validation_0-logloss:0.29902
# [37]	validation_0-logloss:0.29386
# [38]	validation_0-logloss:0.28878
# [39]	validation_0-logloss:0.28350
# [40]	validation_0-logloss:0.27842
# [41]	validation_0-logloss:0.27372
# [42]	validation_0-logloss:0.26879
# [43]	validation_0-logloss:0.26409
# [202]	validation_0-logloss:0.04706
# [203]	validation_0-logloss:0.04683
# [204]	validation_0-logloss:0.04653
# [205]	validation_0-logloss:0.04622
# [206]	validation_0-logloss:0.04600
# [207]	validation_0-logloss:0.04572
# [208]	validation_0-logloss:0.04555
# [209]	validation_0-logloss:0.04525
# [210]	validation_0-logloss:0.04501
# [211]	validation_0-logloss:0.04475
# [212]	validation_0-logloss:0.04447
# [213]	validation_0-logloss:0.04420
# [214]	validation_0-logloss:0.04396
# [215]	validation_0-logloss:0.04371
# [216]	validation_0-logloss:0.04354
# [217]	validation_0-logloss:0.04328
# [218]	validation_0-logloss:0.04306
# [219]	validation_0-logloss:0.04282
# [220]	validation_0-logloss:0.04260
# [221]	validation_0-logloss:0.04237
# [222]	validation_0-logloss:0.04216
# [223]	validation_0-logloss:0.04189
# [224]	validation_0-logloss:0.04168
# [225]	validation_0-logloss:0.04144
# [226]	validation_0-logloss:0.04123
# [227]	validation_0-logloss:0.04099
# [228]	validation_0-logloss:0.04076
# [229]	validation_0-logloss:0.04057
# [230]	validation_0-logloss:0.04038
# [231]	validation_0-logloss:0.04015
# [232]	validation_0-logloss:0.04001
# [233]	validation_0-logloss:0.03986
# [234]	validation_0-logloss:0.03960
# [235]	validation_0-logloss:0.03949
# [236]	validation_0-logloss:0.03927
# [237]	validation_0-logloss:0.03906
# [238]	validation_0-logloss:0.03890
# [239]	validation_0-logloss:0.03871
# [240]	validation_0-logloss:0.03850
# [241]	validation_0-logloss:0.03832
# [242]	validation_0-logloss:0.03816
# [243]	validation_0-logloss:0.03800
# [244]	validation_0-logloss:0.03787
# [245]	validation_0-logloss:0.03766
# [246]	validation_0-logloss:0.03749
# [247]	validation_0-logloss:0.03730
# [248]	validation_0-logloss:0.03713
# [249]	validation_0-logloss:0.03699
# [250]	validation_0-logloss:0.03678
# [251]	validation_0-logloss:0.03666
# [252]	validation_0-logloss:0.03649
# [253]	validation_0-logloss:0.03632
# [254]	validation_0-logloss:0.03616
# [255]	validation_0-logloss:0.03607
# [256]	validation_0-logloss:0.03591
# [257]	validation_0-logloss:0.03570
# [258]	validation_0-logloss:0.03555
# [259]	validation_0-logloss:0.03538
# [260]	validation_0-logloss:0.03523
# [261]	validation_0-logloss:0.03511
# [262]	validation_0-logloss:0.03499
# [263]	validation_0-logloss:0.03485
# [264]	validation_0-logloss:0.03470
# [265]	validation_0-logloss:0.03458
# [266]	validation_0-logloss:0.03442
# [267]	validation_0-logloss:0.03427
# [268]	validation_0-logloss:0.03417
# [269]	validation_0-logloss:0.03407
# [270]	validation_0-logloss:0.03391
# [271]	validation_0-logloss:0.03379
# [272]	validation_0-logloss:0.03369
# [273]	validation_0-logloss:0.03358
# [274]	validation_0-logloss:0.03350
# [275]	validation_0-logloss:0.03341
# [276]	validation_0-logloss:0.03323
# [277]	validation_0-logloss:0.03313
# [278]	validation_0-logloss:0.03301
# [279]	validation_0-logloss:0.03287
# [280]	validation_0-logloss:0.03274
# [281]	validation_0-logloss:0.03264
# [282]	validation_0-logloss:0.03256
# [283]	validation_0-logloss:0.03250
# [284]	validation_0-logloss:0.03237
# [285]	validation_0-logloss:0.03225
# [286]	validation_0-logloss:0.03216
# [287]	validation_0-logloss:0.03205
# [288]	validation_0-logloss:0.03197
# [289]	validation_0-logloss:0.03183
# [290]	validation_0-logloss:0.03171
# [291]	validation_0-logloss:0.03159
# [292]	validation_0-logloss:0.03146
# [293]	validation_0-logloss:0.03135
# [294]	validation_0-logloss:0.03123
# [295]	validation_0-logloss:0.03114
# [296]	validation_0-logloss:0.03102
# [297]	validation_0-logloss:0.03091
# [298]	validation_0-logloss:0.03080
# [299]	validation_0-logloss:0.03068
# [300]	validation_0-logloss:0.03063
# [301]	validation_0-logloss:0.03055
# [302]	validation_0-logloss:0.03047
# [303]	validation_0-logloss:0.03037
# [304]	validation_0-logloss:0.03029
# [305]	validation_0-logloss:0.03017
# [306]	validation_0-logloss:0.03007
# [307]	validation_0-logloss:0.02998
# [308]	validation_0-logloss:0.02989
# [309]	validation_0-logloss:0.02979
# [310]	validation_0-logloss:0.02970
# [311]	validation_0-logloss:0.02959
# [312]	validation_0-logloss:0.02949
# [313]	validation_0-logloss:0.02942
# [314]	validation_0-logloss:0.02935
# [315]	validation_0-logloss:0.02928
# [316]	validation_0-logloss:0.02918
# [317]	validation_0-logloss:0.02907
# [318]	validation_0-logloss:0.02898
# [319]	validation_0-logloss:0.02891
# [320]	validation_0-logloss:0.02882
# [321]	validation_0-logloss:0.02875
# [322]	validation_0-logloss:0.02869
# [323]	validation_0-logloss:0.02867
# [324]	validation_0-logloss:0.02859
# [325]	validation_0-logloss:0.02852
# [326]	validation_0-logloss:0.02845
# [327]	validation_0-logloss:0.02838
# [328]	validation_0-logloss:0.02835
# [329]	validation_0-logloss:0.02829
# [330]	validation_0-logloss:0.02822
# [331]	validation_0-logloss:0.02813
# [332]	validation_0-logloss:0.02804
# [333]	validation_0-logloss:0.02795
# [334]	validation_0-logloss:0.02790
# [335]	validation_0-logloss:0.02784
# [336]	validation_0-logloss:0.02775
# [337]	validation_0-logloss:0.02768
# [338]	validation_0-logloss:0.02762
# [339]	validation_0-logloss:0.02757
# [340]	validation_0-logloss:0.02753
# [341]	validation_0-logloss:0.02749
# [342]	validation_0-logloss:0.02741
# [343]	validation_0-logloss:0.02734
# [344]	validation_0-logloss:0.02726
# [345]	validation_0-logloss:0.02720
# [346]	validation_0-logloss:0.02713
# [347]	validation_0-logloss:0.02706
# [348]	validation_0-logloss:0.02702
# [349]	validation_0-logloss:0.02692
# [350]	validation_0-logloss:0.02685
# [351]	validation_0-logloss:0.02677
# [352]	validation_0-logloss:0.02671
# [353]	validation_0-logloss:0.02664
# [354]	validation_0-logloss:0.02655
# [355]	validation_0-logloss:0.02648
# [356]	validation_0-logloss:0.02643
# [357]	validation_0-logloss:0.02635
# [358]	validation_0-logloss:0.02631
# [359]	validation_0-logloss:0.02626
# [360]	validation_0-logloss:0.02620
# [361]	validation_0-logloss:0.02616
# [362]	validation_0-logloss:0.02609
# [363]	validation_0-logloss:0.02602
# [364]	validation_0-logloss:0.02596
# [365]	validation_0-logloss:0.02592
# [366]	validation_0-logloss:0.02587
# [367]	validation_0-logloss:0.02584
# [368]	validation_0-logloss:0.02580
# [369]	validation_0-logloss:0.02575
# [370]	validation_0-logloss:0.02572
# [371]	validation_0-logloss:0.02564
# [372]	validation_0-logloss:0.02562
# [373]	validation_0-logloss:0.02558
# [374]	validation_0-logloss:0.02551
# [375]	validation_0-logloss:0.02548
# [376]	validation_0-logloss:0.02546
# [377]	validation_0-logloss:0.02543
# [378]	validation_0-logloss:0.02539
# [379]	validation_0-logloss:0.02532
# [380]	validation_0-logloss:0.02525
# [381]	validation_0-logloss:0.02519
# [382]	validation_0-logloss:0.02517
# [383]	validation_0-logloss:0.02509
# [384]	validation_0-logloss:0.02504
# [385]	validation_0-logloss:0.02498
# [386]	validation_0-logloss:0.02493
# [387]	validation_0-logloss:0.02486
# [388]	validation_0-logloss:0.02481
# [389]	validation_0-logloss:0.02474
# [390]	validation_0-logloss:0.02468
# [391]	validation_0-logloss:0.02461
# [392]	validation_0-logloss:0.02455
# [393]	validation_0-logloss:0.02451
# [394]	validation_0-logloss:0.02443
# [395]	validation_0-logloss:0.02438
# [396]	validation_0-logloss:0.02435
# [397]	validation_0-logloss:0.02431
# [398]	validation_0-logloss:0.02429
# [399]	validation_0-logloss:0.02424
# [400]	validation_0-logloss:0.02421
# [401]	validation_0-logloss:0.02415
# [402]	validation_0-logloss:0.02408
# [403]	validation_0-logloss:0.02406
# [404]	validation_0-logloss:0.02406
# [405]	validation_0-logloss:0.02400
# [406]	validation_0-logloss:0.02397
# [407]	validation_0-logloss:0.02392
# [408]	validation_0-logloss:0.02388
# [409]	validation_0-logloss:0.02384
# [410]	validation_0-logloss:0.02378
# [411]	validation_0-logloss:0.02376
# [412]	validation_0-logloss:0.02369
# [413]	validation_0-logloss:0.02366
# [414]	validation_0-logloss:0.02362
# [415]	validation_0-logloss:0.02360
# [416]	validation_0-logloss:0.02357
# [417]	validation_0-logloss:0.02352
# [418]	validation_0-logloss:0.02350
# [419]	validation_0-logloss:0.02346
# [420]	validation_0-logloss:0.02344
# [421]	validation_0-logloss:0.02342
# [422]	validation_0-logloss:0.02341
# [423]	validation_0-logloss:0.02337
# [424]	validation_0-logloss:0.02331
# [425]	validation_0-logloss:0.02322
# [426]	validation_0-logloss:0.02322
# [427]	validation_0-logloss:0.02320
# [428]	validation_0-logloss:0.02319
# [429]	validation_0-logloss:0.02316
# [430]	validation_0-logloss:0.02314
# [431]	validation_0-logloss:0.02311
# [432]	validation_0-logloss:0.02306
# [433]	validation_0-logloss:0.02301
# [434]	validation_0-logloss:0.02294
# [435]	validation_0-logloss:0.02289
# [436]	validation_0-logloss:0.02288
# [437]	validation_0-logloss:0.02281
# [438]	validation_0-logloss:0.02279
# [439]	validation_0-logloss:0.02279
# [440]	validation_0-logloss:0.02276
# [441]	validation_0-logloss:0.02272
# [442]	validation_0-logloss:0.02271
# [443]	validation_0-logloss:0.02267
# [444]	validation_0-logloss:0.02262
# [445]	validation_0-logloss:0.02259
# [446]	validation_0-logloss:0.02252
# [447]	validation_0-logloss:0.02250
# [448]	validation_0-logloss:0.02248
# [449]	validation_0-logloss:0.02245
# [450]	validation_0-logloss:0.02243
# [451]	validation_0-logloss:0.02242
# [452]	validation_0-logloss:0.02238
# [453]	validation_0-logloss:0.02235
# [454]	validation_0-logloss:0.02232
# [455]	validation_0-logloss:0.02229
# [456]	validation_0-logloss:0.02222
# [457]	validation_0-logloss:0.02218
# [458]	validation_0-logloss:0.02214
# [459]	validation_0-logloss:0.02210
# [460]	validation_0-logloss:0.02208
# [461]	validation_0-logloss:0.02206
# [462]	validation_0-logloss:0.02201
# [463]	validation_0-logloss:0.02200
# [464]	validation_0-logloss:0.02197
# [465]	validation_0-logloss:0.02193
# [466]	validation_0-logloss:0.02191
# [467]	validation_0-logloss:0.02189
# [468]	validation_0-logloss:0.02187
# [469]	validation_0-logloss:0.02185
# [470]	validation_0-logloss:0.02183
# [471]	validation_0-logloss:0.02180
# [472]	validation_0-logloss:0.02178
# [473]	validation_0-logloss:0.02177
# [474]	validation_0-logloss:0.02173
# [475]	validation_0-logloss:0.02169
# [476]	validation_0-logloss:0.02170
# [477]	validation_0-logloss:0.02166
# [478]	validation_0-logloss:0.02161
# [479]	validation_0-logloss:0.02161
# [480]	validation_0-logloss:0.02157
# [481]	validation_0-logloss:0.02153
# [482]	validation_0-logloss:0.02151
# [483]	validation_0-logloss:0.02148
# [484]	validation_0-logloss:0.02144
# [485]	validation_0-logloss:0.02143
# [486]	validation_0-logloss:0.02140
# [487]	validation_0-logloss:0.02138
# [488]	validation_0-logloss:0.02138
# [489]	validation_0-logloss:0.02136
# [490]	validation_0-logloss:0.02132
# [491]	validation_0-logloss:0.02127
# [492]	validation_0-logloss:0.02124
# [493]	validation_0-logloss:0.02121
# [494]	validation_0-logloss:0.02119
# [495]	validation_0-logloss:0.02115
# [496]	validation_0-logloss:0.02108
# [497]	validation_0-logloss:0.02108
# [498]	validation_0-logloss:0.02106
# [499]	validation_0-logloss:0.02105
# [500]	validation_0-logloss:0.02102
# [501]	validation_0-logloss:0.02100
# [502]	validation_0-logloss:0.02094
# [503]	validation_0-logloss:0.02091
# [504]	validation_0-logloss:0.02087
# [505]	validation_0-logloss:0.02087
# [506]	validation_0-logloss:0.02084
# [507]	validation_0-logloss:0.02080
# [508]	validation_0-logloss:0.02079
# [509]	validation_0-logloss:0.02074
# [510]	validation_0-logloss:0.02072
# [511]	validation_0-logloss:0.02068
# [512]	validation_0-logloss:0.02066
# [513]	validation_0-logloss:0.02065
# [514]	validation_0-logloss:0.02061
# [515]	validation_0-logloss:0.02059
# [516]	validation_0-logloss:0.02058
# [517]	validation_0-logloss:0.02056
# [518]	validation_0-logloss:0.02053
# [519]	validation_0-logloss:0.02052
# [520]	validation_0-logloss:0.02050
# [521]	validation_0-logloss:0.02047
# [522]	validation_0-logloss:0.02045
# [523]	validation_0-logloss:0.02042
# [524]	validation_0-logloss:0.02041
# [525]	validation_0-logloss:0.02041
# [526]	validation_0-logloss:0.02038
# [527]	validation_0-logloss:0.02035
# [528]	validation_0-logloss:0.02035
# [529]	validation_0-logloss:0.02033
# [530]	validation_0-logloss:0.02030
# [531]	validation_0-logloss:0.02030
# [532]	validation_0-logloss:0.02031
# [533]	validation_0-logloss:0.02030
# [534]	validation_0-logloss:0.02026
# [535]	validation_0-logloss:0.02024
# [536]	validation_0-logloss:0.02023
# [537]	validation_0-logloss:0.02022
# [538]	validation_0-logloss:0.02018
# [539]	validation_0-logloss:0.02015
# [540]	validation_0-logloss:0.02013
# [541]	validation_0-logloss:0.02011
# [542]	validation_0-logloss:0.02010
# [543]	validation_0-logloss:0.02011
# [544]	validation_0-logloss:0.02008
# [545]	validation_0-logloss:0.02009
# [546]	validation_0-logloss:0.02004
# [547]	validation_0-logloss:0.02001
# [548]	validation_0-logloss:0.01997
# [549]	validation_0-logloss:0.01995
# [550]	validation_0-logloss:0.01992
# [551]	validation_0-logloss:0.01990
# [552]	validation_0-logloss:0.01989
# [553]	validation_0-logloss:0.01985
# [554]	validation_0-logloss:0.01982
# [555]	validation_0-logloss:0.01979
# [556]	validation_0-logloss:0.01978
# [557]	validation_0-logloss:0.01978
# [558]	validation_0-logloss:0.01976
# [559]	validation_0-logloss:0.01974
# [560]	validation_0-logloss:0.01971
# [561]	validation_0-logloss:0.01971
# [562]	validation_0-logloss:0.01970
# [563]	validation_0-logloss:0.01970
# [564]	validation_0-logloss:0.01967
# [565]	validation_0-logloss:0.01967
# [566]	validation_0-logloss:0.01966
# [567]	validation_0-logloss:0.01964
# [568]	validation_0-logloss:0.01961
# [569]	validation_0-logloss:0.01959
# [570]	validation_0-logloss:0.01957
# [571]	validation_0-logloss:0.01954
# [572]	validation_0-logloss:0.01953
# [573]	validation_0-logloss:0.01949
# [574]	validation_0-logloss:0.01946
# [575]	validation_0-logloss:0.01945
# [576]	validation_0-logloss:0.01944
# [577]	validation_0-logloss:0.01942
# [578]	validation_0-logloss:0.01940
# [579]	validation_0-logloss:0.01937
# [580]	validation_0-logloss:0.01935
# [581]	validation_0-logloss:0.01932
# [582]	validation_0-logloss:0.01930
# [583]	validation_0-logloss:0.01929
# [584]	validation_0-logloss:0.01929
# [585]	validation_0-logloss:0.01924
# [586]	validation_0-logloss:0.01921
# [587]	validation_0-logloss:0.01921
# [588]	validation_0-logloss:0.01921
# [589]	validation_0-logloss:0.01920
# [590]	validation_0-logloss:0.01917
# [591]	validation_0-logloss:0.01916
# [592]	validation_0-logloss:0.01915
# [593]	validation_0-logloss:0.01913
# [594]	validation_0-logloss:0.01914
# [595]	validation_0-logloss:0.01912
# [675]	validation_0-logloss:0.01825
# [676]	validation_0-logloss:0.01822
# [677]	validation_0-logloss:0.01821
# [678]	validation_0-logloss:0.01819
# [679]	validation_0-logloss:0.01818
# [680]	validation_0-logloss:0.01816
# [681]	validation_0-logloss:0.01814
# [682]	validation_0-logloss:0.01814
# [683]	validation_0-logloss:0.01812
# [684]	validation_0-logloss:0.01811
# [685]	validation_0-logloss:0.01811
# [686]	validation_0-logloss:0.01813
# [687]	validation_0-logloss:0.01810
# [688]	validation_0-logloss:0.01810
# [689]	validation_0-logloss:0.01809
# [690]	validation_0-logloss:0.01808
# [691]	validation_0-logloss:0.01805
# [692]	validation_0-logloss:0.01806
# [693]	validation_0-logloss:0.01803
# [694]	validation_0-logloss:0.01801
# [695]	validation_0-logloss:0.01800
# [696]	validation_0-logloss:0.01799
# [697]	validation_0-logloss:0.01798
# [698]	validation_0-logloss:0.01798
# [699]	validation_0-logloss:0.01798
# [700]	validation_0-logloss:0.01798
# [701]	validation_0-logloss:0.01798
# [702]	validation_0-logloss:0.01798
# [703]	validation_0-logloss:0.01795
# [704]	validation_0-logloss:0.01793
# [705]	validation_0-logloss:0.01793
# [706]	validation_0-logloss:0.01795
# [707]	validation_0-logloss:0.01792
# [708]	validation_0-logloss:0.01792
# [709]	validation_0-logloss:0.01791
# [710]	validation_0-logloss:0.01791
# [711]	validation_0-logloss:0.01791
# [712]	validation_0-logloss:0.01792
# [713]	validation_0-logloss:0.01790
# [714]	validation_0-logloss:0.01788
# [715]	validation_0-logloss:0.01787
# [716]	validation_0-logloss:0.01786
# [717]	validation_0-logloss:0.01785
# [718]	validation_0-logloss:0.01785
# [719]	validation_0-logloss:0.01787
# [720]	validation_0-logloss:0.01785
# [721]	validation_0-logloss:0.01785
# [722]	validation_0-logloss:0.01784
# [723]	validation_0-logloss:0.01783
# [724]	validation_0-logloss:0.01783
# [725]	validation_0-logloss:0.01781
# [726]	validation_0-logloss:0.01781
# [727]	validation_0-logloss:0.01780
# [728]	validation_0-logloss:0.01780
# [729]	validation_0-logloss:0.01779
# [730]	validation_0-logloss:0.01779
# [731]	validation_0-logloss:0.01778
# [732]	validation_0-logloss:0.01775
# [733]	validation_0-logloss:0.01773
# [734]	validation_0-logloss:0.01774
# [735]	validation_0-logloss:0.01771
# [736]	validation_0-logloss:0.01770
# [737]	validation_0-logloss:0.01769
# [738]	validation_0-logloss:0.01769
# [739]	validation_0-logloss:0.01771
# [740]	validation_0-logloss:0.01770
# [741]	validation_0-logloss:0.01770
# [742]	validation_0-logloss:0.01769
# [743]	validation_0-logloss:0.01767
# [744]	validation_0-logloss:0.01767
# [745]	validation_0-logloss:0.01767
# [746]	validation_0-logloss:0.01765
# [747]	validation_0-logloss:0.01763
# [748]	validation_0-logloss:0.01763
# [749]	validation_0-logloss:0.01763
# [750]	validation_0-logloss:0.01764
# [751]	validation_0-logloss:0.01762
# [752]	validation_0-logloss:0.01760
# [753]	validation_0-logloss:0.01759
# [833]	validation_0-logloss:0.01710
# [834]	validation_0-logloss:0.01709
# [835]	validation_0-logloss:0.01709
# [836]	validation_0-logloss:0.01707
# [837]	validation_0-logloss:0.01706
# [838]	validation_0-logloss:0.01705
# [839]	validation_0-logloss:0.01705
# [840]	validation_0-logloss:0.01706
# [841]	validation_0-logloss:0.01706
# [842]	validation_0-logloss:0.01705
# [843]	validation_0-logloss:0.01704
# [844]	validation_0-logloss:0.01704
# [845]	validation_0-logloss:0.01703
# [846]	validation_0-logloss:0.01703
# [847]	validation_0-logloss:0.01702
# [848]	validation_0-logloss:0.01702
# [849]	validation_0-logloss:0.01701
# [850]	validation_0-logloss:0.01699
# [851]	validation_0-logloss:0.01699
# [852]	validation_0-logloss:0.01699
# [853]	validation_0-logloss:0.01697
# [854]	validation_0-logloss:0.01698
# [855]	validation_0-logloss:0.01697
# [856]	validation_0-logloss:0.01698
# [857]	validation_0-logloss:0.01698
# [858]	validation_0-logloss:0.01698
# [859]	validation_0-logloss:0.01696
# [860]	validation_0-logloss:0.01696
# [861]	validation_0-logloss:0.01697
# [862]	validation_0-logloss:0.01698
# [863]	validation_0-logloss:0.01697
# [864]	validation_0-logloss:0.01697
# [865]	validation_0-logloss:0.01697
# [866]	validation_0-logloss:0.01697
# [867]	validation_0-logloss:0.01697
# [868]	validation_0-logloss:0.01696
# [869]	validation_0-logloss:0.01694
# [870]	validation_0-logloss:0.01693
# [871]	validation_0-logloss:0.01693
# [872]	validation_0-logloss:0.01693
# [873]	validation_0-logloss:0.01692
# [874]	validation_0-logloss:0.01691
# [875]	validation_0-logloss:0.01690
# [876]	validation_0-logloss:0.01690
# [877]	validation_0-logloss:0.01689
# [878]	validation_0-logloss:0.01689
# [879]	validation_0-logloss:0.01689
# [880]	validation_0-logloss:0.01688
# [881]	validation_0-logloss:0.01687
# [882]	validation_0-logloss:0.01688
# [883]	validation_0-logloss:0.01688
# [884]	validation_0-logloss:0.01687
# [885]	validation_0-logloss:0.01687
# [886]	validation_0-logloss:0.01686
# [887]	validation_0-logloss:0.01687
# [888]	validation_0-logloss:0.01685
# [889]	validation_0-logloss:0.01685
# [890]	validation_0-logloss:0.01684
# [891]	validation_0-logloss:0.01685
# [892]	validation_0-logloss:0.01683
# [893]	validation_0-logloss:0.01681
# [894]	validation_0-logloss:0.01680
# [895]	validation_0-logloss:0.01680
# [896]	validation_0-logloss:0.01680
# [897]	validation_0-logloss:0.01680
# [898]	validation_0-logloss:0.01681
# [899]	validation_0-logloss:0.01679
# [900]	validation_0-logloss:0.01677
# [901]	validation_0-logloss:0.01675
# [902]	validation_0-logloss:0.01674
# [903]	validation_0-logloss:0.01672
# [904]	validation_0-logloss:0.01671
# [905]	validation_0-logloss:0.01670
# [906]	validation_0-logloss:0.01670
# [907]	validation_0-logloss:0.01668
# [908]	validation_0-logloss:0.01666
# [909]	validation_0-logloss:0.01665
# [910]	validation_0-logloss:0.01665
# [911]	validation_0-logloss:0.01667
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /usr/local/lib/python3.12/dist-packages/IPython/core/formatters.py in __call__(self, obj, include, exclude)
#     968
#     969             if method is not None:
# --> 970                 return method(include=include, exclude=exclude)
#     971             return None
#     972         else:
#
# /usr/local/lib/python3.12/dist-packages/sklearn/base.py in _repr_mimebundle_(self, **kwargs)
#     467         output = {"text/plain": repr(self)}
#     468         if get_config()["display"] == "diagram":
# --> 469             output["text/html"] = estimator_html_repr(self)
#     470         return output
#     471
#
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/_estimator_html_repr.py in estimator_html_repr(estimator)
#     385     else:
#     386         try:
# --> 387             check_is_fitted(estimator)
#     388             status_label = "<span>Fitted</span>"
#     389             is_fitted_css_class = "fitted"
#
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py in check_is_fitted(estimator, attributes, msg, all_or_any)
#    1749         raise TypeError("%s is not an estimator instance." % (estimator))
#    1750
# -> 1751     tags = get_tags(estimator)
#    1752
#    1753     if not tags.requires_fit and attributes is None:
#
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/_tags.py in get_tags(estimator)
#     428         for klass in reversed(type(estimator).mro()):
#     429             if "__sklearn_tags__" in vars(klass):
# --> 430                 sklearn_tags_provider[klass] = klass.__sklearn_tags__(estimator)  # type: ignore[attr-defined]
#     431                 class_order.append(klass)
#     432             elif "_more_tags" in vars(klass):
#
# /usr/local/lib/python3.12/dist-packages/sklearn/base.py in __sklearn_tags__(self)
#     538
#     539     def __sklearn_tags__(self):
# --> 540         tags = super().__sklearn_tags__()
#     541         tags.estimator_type = "classifier"
#     542         tags.classifier_tags = ClassifierTags()
#
# AttributeError: 'super' object has no attribute '__sklearn_tags__'
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /usr/local/lib/python3.12/dist-packages/IPython/core/formatters.py in __call__(self, obj)
#     343             method = get_real_method(obj, self.print_method)
#     344             if method is not None:
# --> 345                 return method()
#     346             return None
#     347         else:
#
# /usr/local/lib/python3.12/dist-packages/sklearn/base.py in _repr_html_inner(self)
#     461         on `get_config()["display"]`.
#     462         """
# --> 463         return estimator_html_repr(self)
#     464
#     465     def _repr_mimebundle_(self, **kwargs):
#
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/_estimator_html_repr.py in estimator_html_repr(estimator)
#     385     else:
#     386         try:
# --> 387             check_is_fitted(estimator)
#     388             status_label = "<span>Fitted</span>"
#     389             is_fitted_css_class = "fitted"
#
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py in check_is_fitted(estimator, attributes, msg, all_or_any)
#    1749         raise TypeError("%s is not an estimator instance." % (estimator))
#    1750
# -> 1751     tags = get_tags(estimator)
#    1752
#    1753     if not tags.requires_fit and attributes is None:
#
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/_tags.py in get_tags(estimator)
#     428         for klass in reversed(type(estimator).mro()):
#     429             if "__sklearn_tags__" in vars(klass):
# --> 430                 sklearn_tags_provider[klass] = klass.__sklearn_tags__(estimator)  # type: ignore[attr-defined]
#     431                 class_order.append(klass)
#     432             elif "_more_tags" in vars(klass):
#
# /usr/local/lib/python3.12/dist-packages/sklearn/base.py in __sklearn_tags__(self)
#     538
#     539     def __sklearn_tags__(self):
# --> 540         tags = super().__sklearn_tags__()
#     541         tags.estimator_type = "classifier"
#     542         tags.classifier_tags = ClassifierTags()
#
# AttributeError: 'super' object has no attribute '__sklearn_tags__'
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=0.9, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric='logloss',
#               feature_types=None, gamma=None, gpu_id=None, grow_policy=None,
#               importance_type=None, interaction_constraints=None,
#               learning_rate=0.03, max_bin=None, max_cat_threshold=None,
#               max_cat_to_onehot=None, max_delta_step=None, max_depth=7,
#               max_leaves=None, min_child_weight=None, missing=nan,
#               monotone_constraints=None, n_estimators=1000, n_jobs=None,
#               num_parallel_tree=None, predictor='gpu_predictor',
#               random_state=None, ...)

# %%
y_pred = model_xgb.predict(X_test)
print("\nAccuracy:", accuracy_score(y_test, y_pred))
print("\nClassification Report:\n", classification_report(y_test, y_pred))
# Out:
# Accuracy: 0.9577205882352942
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.94      0.98      0.96       544
#            1       0.98      0.93      0.96       544
#
#     accuracy                           0.96      1088
#    macro avg       0.96      0.96      0.96      1088
# weighted avg       0.96      0.96      0.96      1088

# %%
with open("voice_classifier.pkl", "wb") as f:
    pickle.dump(model_xgb, f)
print("XGBoost model saved as voice_classifier.pkl")
# Out:
# XGBoost model saved as voice_classifier.pkl

# %%
def predict_voice(audio_path):
    emb = extract_embedding(audio_path).reshape(1, -1)
    with open("voice_classifier.pkl", "rb") as f:
        saved_model = pickle.load(f)
    pred = saved_model.predict(emb)[0]
    return "REAL" if pred == 0 else "FAKE"



print(predict_voice("sample.wav")) # The voice is real
# Out:
# REAL
